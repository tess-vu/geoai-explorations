# %% [markdown]
# ## Using Fiona to manipuate shapefiles and do spatial analysis
# Fiona is an excellant tool for spatial manipulation. This session show you how to use fiona to read and write shapefiles. Shapely and Fiona. These libraries are essentially wrappers for GEOS and OGR, respectively, which provide clean, Pythonic interfaces for performing the processing, while still keeping the performance capabilities of the underlying libraries.
#
# This session will just include how to use fiona to open shapefile. We will do more advanced analysis next week using `Fiona`
#
#
#
# References:
#
# Pandas Tutorial, https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
#
# Fiona Manual, http://toblerity.org/fiona/manual.html

# %% [markdown]
# #### 1. Read the metadata of shapefiles using `fiona`
# You may find the `geopandas` is not flexible in many cases. Sometime you get error message using `geopandas`, it is very difficult to debug, because you don't know how `geopandas` conduct the spatial operations. Here we introduce a lower level module `fiona` and `shapely`, which will give you more flexibility, but also a little bit difficulty. Actually `geopandas` is developed on top of `fiona` and `shapely`.

# %% [markdown]
# Read shapefile and loop all features.

# %%
# get the meta data of shapefile, such as spatial reference, field names, etc
import fiona
from fiona.crs import to_string
from shapely.geometry import mapping, shape

neighborhood_shp = 'data/census-tract-data.shp'

with fiona.open(neighborhood_shp, 'r') as nb_lyr:
    driver = nb_lyr.driver # the driver of the shapefile
    schema = nb_lyr.schema  #schema of shapefile
    crs = nb_lyr.crs   # coordinate reference system of the shapefile
    meta = nb_lyr.meta # more details about the metadata of the shapefile

# %% [markdown]
# Let's take a look at what those metadata look like

# %%
print ('The driver is:', driver)
print ('The schema is:', schema)
print ('The coordinate reference system is:', crs)
print ('the metadata is:', meta)
# Out:
# The driver is: ESRI Shapefile
# The schema is: {'properties': {'STATEFP': 'str:80', 'COUNTYFP': 'str:80', 'TRACTCE': 'str:80', 'GEOID': 'str:80', 'NAME_x': 'str:80', 'NAMELSAD': 'str:80', 'MTFCC': 'str:80', 'FUNCSTAT': 'str:80', 'ALAND': 'int:18', 'AWATER': 'int:18', 'INTPTLAT': 'str:80', 'INTPTLON': 'str:80', 'NAME_y': 'str:80', 'GEO_ID': 'str:80', 'white_popu': 'str:80', 'non-hispan': 'str:80', 'black_popu': 'str:80', 'asian_popu': 'str:80', 'hispanic_p': 'str:80', 'total_popu': 'str:80', 'median_hou': 'str:80', 'per_capita': 'str:80', 'built_age': 'str:80', 'less_highs': 'str:80', 'bachelor': 'str:80', 'totaleduca': 'str:80', 'male_und18': 'str:80', 'female_und': 'str:80', 'male65_66': 'str:80', 'male67_69': 'str:80', 'male70_74': 'str:80', 'male75_79': 'str:80', 'male80_84': 'str:80', 'male85_': 'str:80', 'fema_65_66': 'str:80', 'fema_67_69': 'str:80', 'fema70_74': 'str:80', 'fema75_79': 'str:80', 'fema80_84': 'str:80', 'fema85_': 'str:80', 'state': 'str:80', 'county': 'str:80', 'tract': 'str:80'}, 'geometry': 'Polygon'}
# The coordinate reference system is: EPSG:4269
# the metadata is: {'driver': 'ESRI Shapefile', 'schema': {'properties': {'STATEFP': 'str:80', 'COUNTYFP': 'str:80', 'TRACTCE': 'str:80', 'GEOID': 'str:80', 'NAME_x': 'str:80', 'NAMELSAD': 'str:80', 'MTFCC': 'str:80', 'FUNCSTAT': 'str:80', 'ALAND': 'int:18', 'AWATER': 'int:18', 'INTPTLAT': 'str:80', 'INTPTLON': 'str:80', 'NAME_y': 'str:80', 'GEO_ID': 'str:80', 'white_popu': 'str:80', 'non-hispan': 'str:80', 'black_popu': 'str:80', 'asian_popu': 'str:80', 'hispanic_p': 'str:80', 'total_popu': 'str:80', 'median_hou': 'str:80', 'per_capita': 'str:80', 'built_age': 'str:80', 'less_highs': 'str:80', 'bachelor': 'str:80', 'totaleduca': 'str:80', 'male_und18': 'str:80', 'female_und': 'str:80', 'male65_66': 'str:80', 'male67_69': 'str:80', 'male70_74': 'str:80', 'male75_79': 'str:80', 'male80_84': 'str:80', 'male85_': 'str:80', 'fema_65_66': 'str:80', 'fema_67_69': 'str:80', 'fema70_74': 'str:80', 'fema75_79': 'str:80', 'fema80_84': 'str:80', 'fema85_': 'str:80', 'state': 'str:80', 'county': 'str:80', 'tract': 'str:80'}, 'geometry': 'Polygon'}, 'crs': CRS.from_epsg(4269), 'crs_wkt': 'GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4269"]]'}

# %% [markdown]
# Let's print the geometry and attribute of the features in shapefile

# %%
with fiona.open(neighborhood_shp, 'r') as nb_lyr:
    for feat in nb_lyr:
        # attribute of the neighborhood features
        attr = feat['properties']
        name = attr['TRACTCE']  #you can find other attribute based on the metadata of the shapefile
        print('The neighborhod is:', name)
        # get the geometry of the polygon feature
        geom = feat['geometry']
        print ('geom is:', geom)
# Out:
# The neighborhod is: 014500
# geom is: fiona.Geometry(coordinates=[[(-75.15161599999999, 39.974959), ...]], type='Polygon')
# The neighborhod is: 031200
# geom is: fiona.Geometry(coordinates=[[(-75.084171, 40.032312), ...]], type='Polygon')
# The neighborhod is: 021800
# geom is: fiona.Geometry(coordinates=[[(-75.238074, 40.059878999999995), ...]], type='Polygon')
# The neighborhod is: 009100
# geom is: fiona.Geometry(coordinates=[[(-75.202235, 39.961642999999995), ...]], type='Polygon')
# The neighborhod is: 033600
# geom is: fiona.Geometry(coordinates=[[(-75.068074, 40.060824), ...]], type='Polygon')
# The neighborhod is: 004202
# geom is: fiona.Geometry(coordinates=[[(-75.156633, 39.915245999999996), ...]], type='Polygon')
# The neighborhod is: 016800
# geom is: fiona.Geometry(coordinates=[[(-75.173604, 39.990528999999995), ...]], type='Polygon')
# The neighborhod is: 007000
# geom is: fiona.Geometry(coordinates=[[(-75.226761, 39.935006), ...]], type='Polygon')
# The neighborhod is: 029100
# geom is: fiona.Geometry(coordinates=[[(-75.11455, 40.039747), ...]], type='Polygon')
# The neighborhod is: 980100
# geom is: fiona.Geometry(coordinates=[[(-75.232952, 40.083618), ...]], type='Polygon')
# The neighborhod is: 021300
# geom is: fiona.Geometry(coordinates=[[(-75.225849, 40.033505999999996), ...]], type='Polygon')
# The neighborhod is: 030000
# geom is: fiona.Geometry(coordinates=[[(-75.085535, 40.016175), ...]], type='Polygon')
# The neighborhod is: 013300
# geom is: fiona.Geometry(coordinates=[[(-75.166106, 39.963735), ...]], type='Polygon')
# The neighborhod is: 012204
# geom is: fiona.Geometry(coordinates=[[(-75.220665, 40.003944), ...]], type='Polygon')
# The neighborhod is: 012203
# geom is: fiona.Geometry(coordinates=[[(-75.21389099999999, 40.005485), ...]], type='Polygon')
# The neighborhod is: 013602
# geom is: fiona.Geometry(coordinates=[[(-75.185589, 39.972539999999995), ...]], type='Polygon')
# The neighborhod is: 034502
# geom is: fiona.Geometry(coordinates=[[(-75.047286, 40.082932), ...]], type='Polygon')
# The neighborhod is: 000902
# geom is: fiona.Geometry(coordinates=[[(-75.160172, 39.946857), ...]], type='Polygon')
# The neighborhod is: 000804
# geom is: fiona.Geometry(coordinates=[[(-75.171095, 39.948159), ...]], type='Polygon')
# The neighborhod is: 001202
# geom is: fiona.Geometry(coordinates=[[(-75.17499099999999, 39.945116999999996), ...]], type='Polygon')
# The neighborhod is: 001201
# geom is: fiona.Geometry(coordinates=[[(-75.187141, 39.947222), ...]], type='Polygon')
# The neighborhod is: 002702
# geom is: fiona.Geometry(coordinates=[[(-75.152846, 39.925112999999996), ...]], type='Polygon')
# The neighborhod is: 026301
# geom is: fiona.Geometry(coordinates=[[(-75.16899, 40.071473), ...]], type='Polygon')
# The neighborhod is: 029200
# geom is: fiona.Geometry(coordinates=[[(-75.11285, 40.027335), ...]], type='Polygon')
# The neighborhod is: 024400
# geom is: fiona.Geometry(coordinates=[[(-75.169124, 40.023865), ...]], type='Polygon')
# The neighborhod is: 033200
# geom is: fiona.Geometry(coordinates=[[(-75.054287, 40.044447999999996), ...]], type='Polygon')
# The neighborhod is: 980200
# geom is: fiona.Geometry(coordinates=[[(-75.07624899999999, 40.087377), ...]], type='Polygon')
# The neighborhod is: 000100
# geom is: fiona.Geometry(coordinates=[[(-75.15221199999999, 39.949968), ...]], type='Polygon')
# The neighborhod is: 000200
# geom is: fiona.Geometry(coordinates=[[(-75.162886, 39.955329), ...]], type='Polygon')
# The neighborhod is: 000300
# geom is: fiona.Geometry(coordinates=[[(-75.179937, 39.960028), ...]], type='Polygon')
# The neighborhod is: 036700
# geom is: fiona.Geometry(coordinates=[[(-75.149079, 39.956561), ...]], type='Polygon')
# The neighborhod is: 037800
# geom is: fiona.Geometry(coordinates=[[(-75.12348899999999, 39.972651), ...]], type='Polygon')
# The neighborhod is: 037600
# geom is: fiona.Geometry(coordinates=[[(-75.162319, 39.95793), ...]], type='Polygon')
# The neighborhod is: 001001
# geom is: fiona.Geometry(coordinates=[[(-75.153837, 39.942555999999996), ...]], type='Polygon')
# The neighborhod is: 000402
# geom is: fiona.Geometry(coordinates=[[(-75.173371, 39.95256), ...]], type='Polygon')
# The neighborhod is: 036900
# geom is: fiona.Geometry(coordinates=[[(-75.207739, 39.941365999999995), ...]], type='Polygon')
# The neighborhod is: 037300
# geom is: fiona.Geometry(coordinates=[[(-75.19398699999999, 39.905633), ...]], type='Polygon')
# The neighborhod is: 037200
# geom is: fiona.Geometry(coordinates=[[(-75.172237, 39.912468), ...]], type='Polygon')
# The neighborhod is: 038400
# geom is: fiona.Geometry(coordinates=[[(-75.24328799999999, 40.073494), ...]], type='Polygon')
# The neighborhod is: 038600
# geom is: fiona.Geometry(coordinates=[[(-75.22134799999999, 40.072432), ...]], type='Polygon')
# The neighborhod is: 038500
# geom is: fiona.Geometry(coordinates=[[(-75.22731999999999, 40.084244999999996), ...]], type='Polygon')
# The neighborhod is: 025500
# geom is: fiona.Geometry(coordinates=[[(-75.191054, 40.060176), ...]], type='Polygon')
# The neighborhod is: 025600
# geom is: fiona.Geometry(coordinates=[[(-75.19638499999999, 40.066623), ...]], type='Polygon')
# The neighborhod is: 025700
# geom is: fiona.Geometry(coordinates=[[(-75.20256499999999, 40.073277), ...]], type='Polygon')
# The neighborhod is: 025800
# geom is: fiona.Geometry(coordinates=[[(-75.18846099999999, 40.07275), ...]], type='Polygon')
# The neighborhod is: 025900
# geom is: fiona.Geometry(coordinates=[[(-75.18181899999999, 40.079329), ...]], type='Polygon')
# The neighborhod is: 017602
# geom is: fiona.Geometry(coordinates=[[(-75.13868, 39.999041), ...]], type='Polygon')
# The neighborhod is: 017800
# geom is: fiona.Geometry(coordinates=[[(-75.1249, 39.990159), ...]], type='Polygon')
# The neighborhod is: 017900
# geom is: fiona.Geometry(coordinates=[[(-75.122342, 39.987046), ...]], type='Polygon')
# The neighborhod is: 017701
# geom is: fiona.Geometry(coordinates=[[(-75.11998899999999, 39.994167999999995), ...]], type='Polygon')
# The neighborhod is: 035601
# geom is: fiona.Geometry(coordinates=[[(-75.047567, 40.091919999999995), ...]], type='Polygon')
# The neighborhod is: 980400
# geom is: fiona.Geometry(coordinates=[[(-75.253515, 39.876014999999995), ...]], type='Polygon')
# The neighborhod is: 013402
# geom is: fiona.Geometry(coordinates=[[(-75.172707, 39.964576), ...]], type='Polygon')
# The neighborhod is: 013601
# geom is: fiona.Geometry(coordinates=[[(-75.183561, 39.970777999999996), ...]], type='Polygon')
# The neighborhod is: 008801
# geom is: fiona.Geometry(coordinates=[[(-75.200659, 39.952092), ...]], type='Polygon')
# The neighborhod is: 980500
# geom is: fiona.Geometry(coordinates=[[(-75.147211, 40.014995), ...]], type='Polygon')
# The neighborhod is: 015200
# geom is: fiona.Geometry(coordinates=[[(-75.175585, 39.988918), ...]], type='Polygon')
# The neighborhod is: 018300
# geom is: fiona.Geometry(coordinates=[[(-75.08623399999999, 39.998967), ...]], type='Polygon')
# The neighborhod is: 018400
# geom is: fiona.Geometry(coordinates=[[(-75.075687, 40.005553), ...]], type='Polygon')
# The neighborhod is: 019000
# geom is: fiona.Geometry(coordinates=[[(-75.103687, 40.003637), ...]], type='Polygon')
# The neighborhod is: 019100
# geom is: fiona.Geometry(coordinates=[[(-75.11372399999999, 40.004795), ...]], type='Polygon')
# The neighborhod is: 019200
# geom is: fiona.Geometry(coordinates=[[(-75.12495299999999, 40.000116999999996), ...]], type='Polygon')
# The neighborhod is: 019700
# geom is: fiona.Geometry(coordinates=[[(-75.141446, 40.014227), ...]], type='Polygon')
# The neighborhod is: 019800
# geom is: fiona.Geometry(coordinates=[[(-75.147517, 40.009294), ...]], type='Polygon')
# The neighborhod is: 019900
# geom is: fiona.Geometry(coordinates=[[(-75.148842, 40.002955), ...]], type='Polygon')
# The neighborhod is: 020000
# geom is: fiona.Geometry(coordinates=[[(-75.153722, 39.997986999999995), ...]], type='Polygon')
# The neighborhod is: 020200
# geom is: fiona.Geometry(coordinates=[[(-75.16902, 40.008901), ...]], type='Polygon')
# The neighborhod is: 020300
# geom is: fiona.Geometry(coordinates=[[(-75.153246, 40.016174), ...]], type='Polygon')
# The neighborhod is: 020400
# geom is: fiona.Geometry(coordinates=[[(-75.159035, 40.022800000000004), ...]], type='Polygon')
# The neighborhod is: 020500
# geom is: fiona.Geometry(coordinates=[[(-75.175669, 40.016051), ...]], type='Polygon')
# The neighborhod is: 020600
# geom is: fiona.Geometry(coordinates=[[(-75.192405, 40.020495), ...]], type='Polygon')
# The neighborhod is: 020700
# geom is: fiona.Geometry(coordinates=[[(-75.207171, 40.013076999999996), ...]], type='Polygon')
# The neighborhod is: 020800
# geom is: fiona.Geometry(coordinates=[[(-75.206058, 40.014828), ...]], type='Polygon')
# The neighborhod is: 020900
# geom is: fiona.Geometry(coordinates=[[(-75.21484099999999, 40.020593999999996), ...]], type='Polygon')
# The neighborhod is: 021000
# geom is: fiona.Geometry(coordinates=[[(-75.22346, 40.024145999999995), ...]], type='Polygon')
# The neighborhod is: 021100
# geom is: fiona.Geometry(coordinates=[[(-75.211308, 40.02997), ...]], type='Polygon')
# The neighborhod is: 021200
# geom is: fiona.Geometry(coordinates=[[(-75.218533, 40.036744999999996), ...]], type='Polygon')
# The neighborhod is: 021400
# geom is: fiona.Geometry(coordinates=[[(-75.231706, 40.028312), ...]], type='Polygon')
# The neighborhod is: 021500
# geom is: fiona.Geometry(coordinates=[[(-75.235297, 40.03454), ...]], type='Polygon')
# The neighborhod is: 015600
# geom is: fiona.Geometry(coordinates=[[(-75.14544699999999, 39.976228), ...]], type='Polygon')
# The neighborhod is: 015700
# geom is: fiona.Geometry(coordinates=[[(-75.13941, 39.976333), ...]], type='Polygon')
# The neighborhod is: 015800
# geom is: fiona.Geometry(coordinates=[[(-75.134436, 39.970365), ...]], type='Polygon')
# The neighborhod is: 016000
# geom is: fiona.Geometry(coordinates=[[(-75.130448, 39.978589), ...]], type='Polygon')
# The neighborhod is: 016100
# geom is: fiona.Geometry(coordinates=[[(-75.13319, 39.980134), ...]], type='Polygon')
# The neighborhod is: 016200
# geom is: fiona.Geometry(coordinates=[[(-75.14512599999999, 39.986484999999995), ...]], type='Polygon')
# The neighborhod is: 016300
# geom is: fiona.Geometry(coordinates=[[(-75.139571, 39.986253999999995), ...]], type='Polygon')
# The neighborhod is: 016400
# geom is: fiona.Geometry(coordinates=[[(-75.148378, 39.991216), ...]], type='Polygon')
# The neighborhod is: 016500
# geom is: fiona.Geometry(coordinates=[[(-75.15307299999999, 39.990634), ...]], type='Polygon')
# The neighborhod is: 016600
# geom is: fiona.Geometry(coordinates=[[(-75.156275, 39.986283), ...]], type='Polygon')
# The neighborhod is: 016901
# geom is: fiona.Geometry(coordinates=[[(-75.180073, 39.990189), ...]], type='Polygon')
# The neighborhod is: 017000
# geom is: fiona.Geometry(coordinates=[[(-75.19281, 40.006733), ...]], type='Polygon')
# The neighborhod is: 017100
# geom is: fiona.Geometry(coordinates=[[(-75.187589, 39.99856), ...]], type='Polygon')
# The neighborhod is: 017202
# geom is: fiona.Geometry(coordinates=[[(-75.180106, 39.997367), ...]], type='Polygon')
# The neighborhod is: 027401
# geom is: fiona.Geometry(coordinates=[[(-75.131162, 40.033392), ...]], type='Polygon')
# The neighborhod is: 020101
# geom is: fiona.Geometry(coordinates=[[(-75.15860099999999, 40.005497999999996), ...]], type='Polygon')
# The neighborhod is: 028901
# geom is: fiona.Geometry(coordinates=[[(-75.120481, 40.02109), ...]], type='Polygon')
# The neighborhod is: 030501
# geom is: fiona.Geometry(coordinates=[[(-75.103955, 40.040822), ...]], type='Polygon')
# The neighborhod is: 016702
# geom is: fiona.Geometry(coordinates=[[(-75.16069499999999, 39.988495), ...]], type='Polygon')
# The neighborhod is: 008802
# geom is: fiona.Geometry(coordinates=[[(-75.20580199999999, 39.950984999999996), ...]], type='Polygon')
# The neighborhod is: 021600
# geom is: fiona.Geometry(coordinates=[[(-75.25129799999999, 40.043504999999996), ...]], type='Polygon')
# The neighborhod is: 021700
# geom is: fiona.Geometry(coordinates=[[(-75.235419, 40.048775), ...]], type='Polygon')
# The neighborhod is: 021900
# geom is: fiona.Geometry(coordinates=[[(-75.254376, 40.046571), ...]], type='Polygon')
# The neighborhod is: 022000
# geom is: fiona.Geometry(coordinates=[[(-75.26386, 40.054556999999996), ...]], type='Polygon')
# The neighborhod is: 023100
# geom is: fiona.Geometry(coordinates=[[(-75.208933, 40.067015), ...]], type='Polygon')
# The neighborhod is: 023500
# geom is: fiona.Geometry(coordinates=[[(-75.209918, 40.047059999999995), ...]], type='Polygon')
# The neighborhod is: 023600
# geom is: fiona.Geometry(coordinates=[[(-75.20138399999999, 40.042502), ...]], type='Polygon')
# The neighborhod is: 023700
# geom is: fiona.Geometry(coordinates=[[(-75.194383, 40.050934999999996), ...]], type='Polygon')
# The neighborhod is: 023900
# geom is: fiona.Geometry(coordinates=[[(-75.19293499999999, 40.035463), ...]], type='Polygon')
# The neighborhod is: 024000
# geom is: fiona.Geometry(coordinates=[[(-75.186194, 40.029468), ...]], type='Polygon')
# The neighborhod is: 024100
# geom is: fiona.Geometry(coordinates=[[(-75.181235, 40.033097), ...]], type='Polygon')
# The neighborhod is: 014900
# geom is: fiona.Geometry(coordinates=[[(-75.188571, 39.981698), ...]], type='Polygon')
# The neighborhod is: 014700
# geom is: fiona.Geometry(coordinates=[[(-75.16615999999999, 39.978308), ...]], type='Polygon')
# The neighborhod is: 014800
# geom is: fiona.Geometry(coordinates=[[(-75.17271099999999, 39.979614), ...]], type='Polygon')
# The neighborhod is: 024200
# geom is: fiona.Geometry(coordinates=[[(-75.17473, 40.027620999999996), ...]], type='Polygon')
# The neighborhod is: 024300
# geom is: fiona.Geometry(coordinates=[[(-75.177521, 40.023192), ...]], type='Polygon')
# The neighborhod is: 024500
# geom is: fiona.Geometry(coordinates=[[(-75.16921099999999, 40.032314), ...]], type='Polygon')
# The neighborhod is: 024600
# geom is: fiona.Geometry(coordinates=[[(-75.177757, 40.039401), ...]], type='Polygon')
# The neighborhod is: 017300
# geom is: fiona.Geometry(coordinates=[[(-75.167215, 39.997197), ...]], type='Polygon')
# The neighborhod is: 017400
# geom is: fiona.Geometry(coordinates=[[(-75.15458799999999, 39.993938), ...]], type='Polygon')
# The neighborhod is: 017500
# geom is: fiona.Geometry(coordinates=[[(-75.147699, 39.993781999999996), ...]], type='Polygon')
# The neighborhod is: 017601
# geom is: fiona.Geometry(coordinates=[[(-75.139851, 39.993672), ...]], type='Polygon')
# The neighborhod is: 024700
# geom is: fiona.Geometry(coordinates=[[(-75.17217, 40.038637), ...]], type='Polygon')
# The neighborhod is: 024900
# geom is: fiona.Geometry(coordinates=[[(-75.164529, 40.050306), ...]], type='Polygon')
# The neighborhod is: 025200
# geom is: fiona.Geometry(coordinates=[[(-75.183398, 40.048254), ...]], type='Polygon')
# The neighborhod is: 025400
# geom is: fiona.Geometry(coordinates=[[(-75.18336599999999, 40.059219999999996), ...]], type='Polygon')
# The neighborhod is: 035200
# geom is: fiona.Geometry(coordinates=[[(-75.004795, 40.054747), ...]], type='Polygon')
# The neighborhod is: 980300
# geom is: fiona.Geometry(coordinates=[[(-75.02895199999999, 40.080968), ...]], type='Polygon')
# The neighborhod is: 035500
# geom is: fiona.Geometry(coordinates=[[(-75.041488, 40.087337999999995), ...]], type='Polygon')
# The neighborhod is: 035800
# geom is: fiona.Geometry(coordinates=[[(-75.037842, 40.120213), ...]], type='Polygon')
# The neighborhod is: 035900
# geom is: fiona.Geometry(coordinates=[[(-75.028396, 40.103552), ...]], type='Polygon')
# The neighborhod is: 036000
# geom is: fiona.Geometry(coordinates=[[(-75.023927, 40.100702), ...]], type='Polygon')
# The neighborhod is: 036100
# geom is: fiona.Geometry(coordinates=[[(-75.001796, 40.104929999999996), ...]], type='Polygon')
# The neighborhod is: 026000
# geom is: fiona.Geometry(coordinates=[[(-75.17550899999999, 40.075213999999995), ...]], type='Polygon')
# The neighborhod is: 027500
# geom is: fiona.Geometry(coordinates=[[(-75.13490999999999, 40.036045), ...]], type='Polygon')
# The neighborhod is: 006500
# geom is: fiona.Geometry(coordinates=[[(-75.247028, 39.943414), ...]], type='Polygon')
# The neighborhod is: 006600
# geom is: fiona.Geometry(coordinates=[[(-75.236986, 39.927821), ...]], type='Polygon')
# The neighborhod is: 006700
# geom is: fiona.Geometry(coordinates=[[(-75.232438, 39.92397), ...]], type='Polygon')
# The neighborhod is: 007200
# geom is: fiona.Geometry(coordinates=[[(-75.24005199999999, 39.945917), ...]], type='Polygon')
# The neighborhod is: 001300
# geom is: fiona.Geometry(coordinates=[[(-75.193985, 39.942153999999995), ...]], type='Polygon')
# The neighborhod is: 001600
# geom is: fiona.Geometry(coordinates=[[(-75.15271, 39.940345), ...]], type='Polygon')
# The neighborhod is: 001700
# geom is: fiona.Geometry(coordinates=[[(-75.15321399999999, 39.938108), ...]], type='Polygon')
# The neighborhod is: 007300
# geom is: fiona.Geometry(coordinates=[[(-75.229894, 39.947790999999995), ...]], type='Polygon')
# The neighborhod is: 007400
# geom is: fiona.Geometry(coordinates=[[(-75.221079, 39.940976), ...]], type='Polygon')
# The neighborhod is: 001800
# geom is: fiona.Geometry(coordinates=[[(-75.16636, 39.94003), ...]], type='Polygon')
# The neighborhod is: 001900
# geom is: fiona.Geometry(coordinates=[[(-75.17806999999999, 39.940079999999995), ...]], type='Polygon')
# The neighborhod is: 002100
# geom is: fiona.Geometry(coordinates=[[(-75.18053499999999, 39.936212), ...]], type='Polygon')
# The neighborhod is: 002200
# geom is: fiona.Geometry(coordinates=[[(-75.17385, 39.935449999999996), ...]], type='Polygon')
# The neighborhod is: 002400
# geom is: fiona.Geometry(coordinates=[[(-75.16708299999999, 39.936741999999995), ...]], type='Polygon')
# The neighborhod is: 002500
# geom is: fiona.Geometry(coordinates=[[(-75.154372, 39.932826999999996), ...]], type='Polygon')
# The neighborhod is: 002900
# geom is: fiona.Geometry(coordinates=[[(-75.169494, 39.925596), ...]], type='Polygon')
# The neighborhod is: 003100
# geom is: fiona.Geometry(coordinates=[[(-75.181846, 39.930150999999995), ...]], type='Polygon')
# The neighborhod is: 003200
# geom is: fiona.Geometry(coordinates=[[(-75.19012699999999, 39.931219), ...]], type='Polygon')
# The neighborhod is: 003300
# geom is: fiona.Geometry(coordinates=[[(-75.20528399999999, 39.940446), ...]], type='Polygon')
# The neighborhod is: 007800
# geom is: fiona.Geometry(coordinates=[[(-75.223315, 39.947925), ...]], type='Polygon')
# The neighborhod is: 007900
# geom is: fiona.Geometry(coordinates=[[(-75.22332899999999, 39.948012), ...]], type='Polygon')
# The neighborhod is: 008000
# geom is: fiona.Geometry(coordinates=[[(-75.23126599999999, 39.947935), ...]], type='Polygon')
# The neighborhod is: 008200
# geom is: fiona.Geometry(coordinates=[[(-75.25164699999999, 39.951845999999996), ...]], type='Polygon')
# The neighborhod is: 008301
# geom is: fiona.Geometry(coordinates=[[(-75.250883, 39.959024), ...]], type='Polygon')
# The neighborhod is: 003600
# geom is: fiona.Geometry(coordinates=[[(-75.199855, 39.93266), ...]], type='Polygon')
# The neighborhod is: 003701
# geom is: fiona.Geometry(coordinates=[[(-75.185773, 39.927695), ...]], type='Polygon')
# The neighborhod is: 003702
# geom is: fiona.Geometry(coordinates=[[(-75.18685099999999, 39.922751), ...]], type='Polygon')
# The neighborhod is: 003800
# geom is: fiona.Geometry(coordinates=[[(-75.190298, 39.91644), ...]], type='Polygon')
# The neighborhod is: 003901
# geom is: fiona.Geometry(coordinates=[[(-75.177129, 39.920387999999996), ...]], type='Polygon')
# The neighborhod is: 003902
# geom is: fiona.Geometry(coordinates=[[(-75.178184, 39.915487), ...]], type='Polygon')
# The neighborhod is: 004001
# geom is: fiona.Geometry(coordinates=[[(-75.170309, 39.921884999999996), ...]], type='Polygon')
# The neighborhod is: 015300
# geom is: fiona.Geometry(coordinates=[[(-75.165424, 39.981640999999996), ...]], type='Polygon')
# The neighborhod is: 025300
# geom is: fiona.Geometry(coordinates=[[(-75.18730599999999, 40.055484), ...]], type='Polygon')
# The neighborhod is: 006900
# geom is: fiona.Geometry(coordinates=[[(-75.222351, 39.931047), ...]], type='Polygon')
# The neighborhod is: 035301
# geom is: fiona.Geometry(coordinates=[[(-74.998814, 40.065359), ...]], type='Polygon')
# The neighborhod is: 031900
# geom is: fiona.Geometry(coordinates=[[(-75.073364, 40.025369), ...]], type='Polygon')
# The neighborhod is: 028300
# geom is: fiona.Geometry(coordinates=[[(-75.148245, 40.022959), ...]], type='Polygon')
# The neighborhod is: 008302
# geom is: fiona.Geometry(coordinates=[[(-75.244564, 39.953455), ...]], type='Polygon')
# The neighborhod is: 008400
# geom is: fiona.Geometry(coordinates=[[(-75.240023, 39.955768), ...]], type='Polygon')
# The neighborhod is: 008500
# geom is: fiona.Geometry(coordinates=[[(-75.232045, 39.95478), ...]], type='Polygon')
# The neighborhod is: 009000
# geom is: fiona.Geometry(coordinates=[[(-75.194195, 39.962621999999996), ...]], type='Polygon')
# The neighborhod is: 004002
# geom is: fiona.Geometry(coordinates=[[(-75.17139499999999, 39.916885), ...]], type='Polygon')
# The neighborhod is: 004101
# geom is: fiona.Geometry(coordinates=[[(-75.16331799999999, 39.921471), ...]], type='Polygon')
# The neighborhod is: 004102
# geom is: fiona.Geometry(coordinates=[[(-75.164231, 39.917263), ...]], type='Polygon')
# The neighborhod is: 011200
# geom is: fiona.Geometry(coordinates=[[(-75.23857, 39.976101), ...]], type='Polygon')
# The neighborhod is: 002300
# geom is: fiona.Geometry(coordinates=[[(-75.16763999999999, 39.934149999999995), ...]], type='Polygon')
# The neighborhod is: 006200
# geom is: fiona.Geometry(coordinates=[[(-75.239511, 39.918979), ...]], type='Polygon')
# The neighborhod is: 032300
# geom is: fiona.Geometry(coordinates=[[(-75.057513, 40.021597), ...]], type='Polygon')
# The neighborhod is: 000600
# geom is: fiona.Geometry(coordinates=[[(-75.164338, 39.949346), ...]], type='Polygon')
# The neighborhod is: 001500
# geom is: fiona.Geometry(coordinates=[[(-75.165988, 39.94182), ...]], type='Polygon')
# The neighborhod is: 009200
# geom is: fiona.Geometry(coordinates=[[(-75.213673, 39.960029999999996), ...]], type='Polygon')
# The neighborhod is: 009300
# geom is: fiona.Geometry(coordinates=[[(-75.228318, 39.962033), ...]], type='Polygon')
# The neighborhod is: 009400
# geom is: fiona.Geometry(coordinates=[[(-75.236677, 39.962092999999996), ...]], type='Polygon')
# The neighborhod is: 009500
# geom is: fiona.Geometry(coordinates=[[(-75.240428, 39.963536), ...]], type='Polygon')
# The neighborhod is: 009600
# geom is: fiona.Geometry(coordinates=[[(-75.247464, 39.964507999999995), ...]], type='Polygon')
# The neighborhod is: 010000
# geom is: fiona.Geometry(coordinates=[[(-75.255196, 39.97426), ...]], type='Polygon')
# The neighborhod is: 010100
# geom is: fiona.Geometry(coordinates=[[(-75.24720099999999, 39.970608999999996), ...]], type='Polygon')
# The neighborhod is: 010200
# geom is: fiona.Geometry(coordinates=[[(-75.235599, 39.967239), ...]], type='Polygon')
# The neighborhod is: 010300
# geom is: fiona.Geometry(coordinates=[[(-75.228735, 39.971106999999996), ...]], type='Polygon')
# The neighborhod is: 010400
# geom is: fiona.Geometry(coordinates=[[(-75.223118, 39.969747), ...]], type='Polygon')
# The neighborhod is: 010500
# geom is: fiona.Geometry(coordinates=[[(-75.217767, 39.972626999999996), ...]], type='Polygon')
# The neighborhod is: 036501
# geom is: fiona.Geometry(coordinates=[[(-75.02371, 40.130053), ...]], type='Polygon')
# The neighborhod is: 000801
# geom is: fiona.Geometry(coordinates=[[(-75.18328799999999, 39.949512), ...]], type='Polygon')
# The neighborhod is: 038700
# geom is: fiona.Geometry(coordinates=[[(-75.229772, 40.086757999999996), ...]], type='Polygon')
# The neighborhod is: 038800
# geom is: fiona.Geometry(coordinates=[[(-75.20476699999999, 40.054856), ...]], type='Polygon')
# The neighborhod is: 038900
# geom is: fiona.Geometry(coordinates=[[(-75.177193, 40.05308), ...]], type='Polygon')
# The neighborhod is: 037900
# geom is: fiona.Geometry(coordinates=[[(-75.105064, 39.987072999999995), ...]], type='Polygon')
# The neighborhod is: 038200
# geom is: fiona.Geometry(coordinates=[[(-75.109709, 39.992334), ...]], type='Polygon')
# The neighborhod is: 038000
# geom is: fiona.Geometry(coordinates=[[(-75.090154, 40.004148), ...]], type='Polygon')
# The neighborhod is: 038300
# geom is: fiona.Geometry(coordinates=[[(-75.137529, 40.004304), ...]], type='Polygon')
# The neighborhod is: 039000
# geom is: fiona.Geometry(coordinates=[[(-75.104331, 40.029981), ...]], type='Polygon')
# The neighborhod is: 038100
# geom is: fiona.Geometry(coordinates=[[(-75.069508, 40.010798), ...]], type='Polygon')
# The neighborhod is: 014600
# geom is: fiona.Geometry(coordinates=[[(-75.158782, 39.974481999999995), ...]], type='Polygon')
# The neighborhod is: 026100
# geom is: fiona.Geometry(coordinates=[[(-75.181088, 40.069601), ...]], type='Polygon')
# The neighborhod is: 026200
# geom is: fiona.Geometry(coordinates=[[(-75.175327, 40.065216), ...]], type='Polygon')
# The neighborhod is: 026302
# geom is: fiona.Geometry(coordinates=[[(-75.16342, 40.069331999999996), ...]], type='Polygon')
# The neighborhod is: 026400
# geom is: fiona.Geometry(coordinates=[[(-75.168576, 40.061426), ...]], type='Polygon')
# The neighborhod is: 026500
# geom is: fiona.Geometry(coordinates=[[(-75.160691, 40.056830999999995), ...]], type='Polygon')
# The neighborhod is: 026600
# geom is: fiona.Geometry(coordinates=[[(-75.153342, 40.064806), ...]], type='Polygon')
# The neighborhod is: 026700
# geom is: fiona.Geometry(coordinates=[[(-75.155554, 40.054074), ...]], type='Polygon')
# The neighborhod is: 026900
# geom is: fiona.Geometry(coordinates=[[(-75.137394, 40.054862), ...]], type='Polygon')
# The neighborhod is: 027100
# geom is: fiona.Geometry(coordinates=[[(-75.12833499999999, 40.046386), ...]], type='Polygon')
# The neighborhod is: 027200
# geom is: fiona.Geometry(coordinates=[[(-75.12350099999999, 40.045546), ...]], type='Polygon')
# The neighborhod is: 027300
# geom is: fiona.Geometry(coordinates=[[(-75.12416499999999, 40.032607), ...]], type='Polygon')
# The neighborhod is: 036201
# geom is: fiona.Geometry(coordinates=[[(-74.994348, 40.081680999999996), ...]], type='Polygon')
# The neighborhod is: 036202
# geom is: fiona.Geometry(coordinates=[[(-74.984043, 40.074926), ...]], type='Polygon')
# The neighborhod is: 027700
# geom is: fiona.Geometry(coordinates=[[(-75.157949, 40.049217), ...]], type='Polygon')
# The neighborhod is: 027800
# geom is: fiona.Geometry(coordinates=[[(-75.15143499999999, 40.040866), ...]], type='Polygon')
# The neighborhod is: 028000
# geom is: fiona.Geometry(coordinates=[[(-75.15950699999999, 40.023982), ...]], type='Polygon')
# The neighborhod is: 027600
# geom is: fiona.Geometry(coordinates=[[(-75.144444, 40.040514), ...]], type='Polygon')
# The neighborhod is: 028200
# geom is: fiona.Geometry(coordinates=[[(-75.14682599999999, 40.029602), ...]], type='Polygon')
# The neighborhod is: 028400
# geom is: fiona.Geometry(coordinates=[[(-75.141589, 40.020810999999995), ...]], type='Polygon')
# The neighborhod is: 028500
# geom is: fiona.Geometry(coordinates=[[(-75.135724, 40.023602), ...]], type='Polygon')
# The neighborhod is: 028600
# geom is: fiona.Geometry(coordinates=[[(-75.13327799999999, 40.023821), ...]], type='Polygon')
# The neighborhod is: 028700
# geom is: fiona.Geometry(coordinates=[[(-75.135683, 40.022952), ...]], type='Polygon')
# The neighborhod is: 029000
# geom is: fiona.Geometry(coordinates=[[(-75.123452, 40.025784), ...]], type='Polygon')
# The neighborhod is: 029300
# geom is: fiona.Geometry(coordinates=[[(-75.09703999999999, 40.016017999999995), ...]], type='Polygon')
# The neighborhod is: 029400
# geom is: fiona.Geometry(coordinates=[[(-75.092536, 40.005378), ...]], type='Polygon')
# The neighborhod is: 036203
# geom is: fiona.Geometry(coordinates=[[(-74.982418, 40.065417), ...]], type='Polygon')
# The neighborhod is: 009801
# geom is: fiona.Geometry(coordinates=[[(-75.271309, 39.979275), ...]], type='Polygon')
# The neighborhod is: 012201
# geom is: fiona.Geometry(coordinates=[[(-75.214787, 40.002888), ...]], type='Polygon')
# The neighborhod is: 007101
# geom is: fiona.Geometry(coordinates=[[(-75.229227, 39.937090999999995), ...]], type='Polygon')
# The neighborhod is: 002801
# geom is: fiona.Geometry(coordinates=[[(-75.15910199999999, 39.925931999999996), ...]], type='Polygon')
# The neighborhod is: 029800
# geom is: fiona.Geometry(coordinates=[[(-75.073334, 40.019709), ...]], type='Polygon')
# The neighborhod is: 029900
# geom is: fiona.Geometry(coordinates=[[(-75.080857, 40.011903), ...]], type='Polygon')
# The neighborhod is: 030100
# geom is: fiona.Geometry(coordinates=[[(-75.095897, 40.019604), ...]], type='Polygon')
# The neighborhod is: 030200
# geom is: fiona.Geometry(coordinates=[[(-75.09005599999999, 40.026306999999996), ...]], type='Polygon')
# The neighborhod is: 030600
# geom is: fiona.Geometry(coordinates=[[(-75.10323, 40.051355), ...]], type='Polygon')
# The neighborhod is: 036301
# geom is: fiona.Geometry(coordinates=[[(-74.9768, 40.091201999999996), ...]], type='Polygon')
# The neighborhod is: 036302
# geom is: fiona.Geometry(coordinates=[[(-74.98655099999999, 40.099365999999996), ...]], type='Polygon')
# The neighborhod is: 036303
# geom is: fiona.Geometry(coordinates=[[(-74.98252, 40.104275), ...]], type='Polygon')
# The neighborhod is: 036400
# geom is: fiona.Geometry(coordinates=[[(-75.005391, 40.114802), ...]], type='Polygon')
# The neighborhod is: 030700
# geom is: fiona.Geometry(coordinates=[[(-75.093644, 40.057429), ...]], type='Polygon')
# The neighborhod is: 030800
# geom is: fiona.Geometry(coordinates=[[(-75.086795, 40.052904999999996), ...]], type='Polygon')
# The neighborhod is: 030900
# geom is: fiona.Geometry(coordinates=[[(-75.08897499999999, 40.044332), ...]], type='Polygon')
# The neighborhod is: 031000
# geom is: fiona.Geometry(coordinates=[[(-75.08230999999999, 40.048832), ...]], type='Polygon')
# The neighborhod is: 031300
# geom is: fiona.Geometry(coordinates=[[(-75.077001, 40.039885), ...]], type='Polygon')
# The neighborhod is: 031600
# geom is: fiona.Geometry(coordinates=[[(-75.06432, 40.036314999999995), ...]], type='Polygon')
# The neighborhod is: 031700
# geom is: fiona.Geometry(coordinates=[[(-75.07548799999999, 40.027071), ...]], type='Polygon')
# The neighborhod is: 031800
# geom is: fiona.Geometry(coordinates=[[(-75.084111, 40.031618), ...]], type='Polygon')
# The neighborhod is: 032000
# geom is: fiona.Geometry(coordinates=[[(-75.06240799999999, 40.027271), ...]], type='Polygon')
# The neighborhod is: 032100
# geom is: fiona.Geometry(coordinates=[[(-75.064549, 40.017804), ...]], type='Polygon')
# The neighborhod is: 032500
# geom is: fiona.Geometry(coordinates=[[(-75.051104, 40.026407), ...]], type='Polygon')
# The neighborhod is: 032600
# geom is: fiona.Geometry(coordinates=[[(-75.04677, 40.033682999999996), ...]], type='Polygon')
# The neighborhod is: 989100
# geom is: fiona.Geometry(coordinates=[[(-75.022508, 40.030832), ...]], type='Polygon')
# The neighborhod is: 032900
# geom is: fiona.Geometry(coordinates=[[(-75.033427, 40.039473), ...]], type='Polygon')
# The neighborhod is: 033000
# geom is: fiona.Geometry(coordinates=[[(-75.040594, 40.036859), ...]], type='Polygon')
# The neighborhod is: 033300
# geom is: fiona.Geometry(coordinates=[[(-75.051051, 40.049068999999996), ...]], type='Polygon')
# The neighborhod is: 033400
# geom is: fiona.Geometry(coordinates=[[(-75.060344, 40.051316), ...]], type='Polygon')
# The neighborhod is: 033800
# geom is: fiona.Geometry(coordinates=[[(-75.085571, 40.062689), ...]], type='Polygon')
# The neighborhod is: 033900
# geom is: fiona.Geometry(coordinates=[[(-75.096733, 40.068988999999995), ...]], type='Polygon')
# The neighborhod is: 034000
# geom is: fiona.Geometry(coordinates=[[(-75.080271, 40.0686), ...]], type='Polygon')
# The neighborhod is: 034100
# geom is: fiona.Geometry(coordinates=[[(-75.089828, 40.0756), ...]], type='Polygon')
# The neighborhod is: 034200
# geom is: fiona.Geometry(coordinates=[[(-75.082456, 40.082884), ...]], type='Polygon')
# The neighborhod is: 034400
# geom is: fiona.Geometry(coordinates=[[(-75.069456, 40.094411), ...]], type='Polygon')
# The neighborhod is: 034600
# geom is: fiona.Geometry(coordinates=[[(-75.03508699999999, 40.074616999999996), ...]], type='Polygon')
# The neighborhod is: 034701
# geom is: fiona.Geometry(coordinates=[[(-75.0406, 40.068042), ...]], type='Polygon')
# The neighborhod is: 008602
# geom is: fiona.Geometry(coordinates=[[(-75.22168599999999, 39.955853999999995), ...]], type='Polygon')
# The neighborhod is: 009802
# geom is: fiona.Geometry(coordinates=[[(-75.275468, 39.977429), ...]], type='Polygon')
# The neighborhod is: 037500
# geom is: fiona.Geometry(coordinates=[[(-75.265511, 39.981857), ...]], type='Polygon')
# The neighborhod is: 018001
# geom is: fiona.Geometry(coordinates=[[(-75.117109, 39.98176), ...]], type='Polygon')
# The neighborhod is: 011000
# geom is: fiona.Geometry(coordinates=[[(-75.213469, 39.977790999999996), ...]], type='Polygon')
# The neighborhod is: 011100
# geom is: fiona.Geometry(coordinates=[[(-75.230171, 39.978794), ...]], type='Polygon')
# The neighborhod is: 011300
# geom is: fiona.Geometry(coordinates=[[(-75.23947299999999, 39.981114), ...]], type='Polygon')
# The neighborhod is: 011400
# geom is: fiona.Geometry(coordinates=[[(-75.251063, 39.981601), ...]], type='Polygon')
# The neighborhod is: 011500
# geom is: fiona.Geometry(coordinates=[[(-75.255918, 39.978122), ...]], type='Polygon')
# The neighborhod is: 011800
# geom is: fiona.Geometry(coordinates=[[(-75.24547799999999, 39.986619), ...]], type='Polygon')
# The neighborhod is: 011900
# geom is: fiona.Geometry(coordinates=[[(-75.233672, 39.991882), ...]], type='Polygon')
# The neighborhod is: 012000
# geom is: fiona.Geometry(coordinates=[[(-75.234413, 39.997488), ...]], type='Polygon')
# The neighborhod is: 012100
# geom is: fiona.Geometry(coordinates=[[(-75.227462, 40.000746), ...]], type='Polygon')
# The neighborhod is: 012500
# geom is: fiona.Geometry(coordinates=[[(-75.183323, 39.964374), ...]], type='Polygon')
# The neighborhod is: 013100
# geom is: fiona.Geometry(coordinates=[[(-75.15418199999999, 39.963221999999995), ...]], type='Polygon')
# The neighborhod is: 013500
# geom is: fiona.Geometry(coordinates=[[(-75.175305, 39.967704), ...]], type='Polygon')
# The neighborhod is: 013700
# geom is: fiona.Geometry(coordinates=[[(-75.189882, 39.977933), ...]], type='Polygon')
# The neighborhod is: 003002
# geom is: fiona.Geometry(coordinates=[[(-75.174495, 39.932522999999996), ...]], type='Polygon')
# The neighborhod is: 031401
# geom is: fiona.Geometry(coordinates=[[(-75.07207, 40.045024), ...]], type='Polygon')
# The neighborhod is: 013401
# geom is: fiona.Geometry(coordinates=[[(-75.179683, 39.967416), ...]], type='Polygon')
# The neighborhod is: 018002
# geom is: fiona.Geometry(coordinates=[[(-75.111221, 39.985268), ...]], type='Polygon')
# The neighborhod is: 013800
# geom is: fiona.Geometry(coordinates=[[(-75.18066, 39.973161), ...]], type='Polygon')
# The neighborhod is: 013900
# geom is: fiona.Geometry(coordinates=[[(-75.177863, 39.973832), ...]], type='Polygon')
# The neighborhod is: 014100
# geom is: fiona.Geometry(coordinates=[[(-75.159442, 39.971467), ...]], type='Polygon')
# The neighborhod is: 014200
# geom is: fiona.Geometry(coordinates=[[(-75.146743, 39.969291999999996), ...]], type='Polygon')
# The neighborhod is: 035701
# geom is: fiona.Geometry(coordinates=[[(-75.033238, 40.106282), ...]], type='Polygon')
# The neighborhod is: 035702
# geom is: fiona.Geometry(coordinates=[[(-75.048542, 40.112729), ...]], type='Polygon')
# The neighborhod is: 033701
# geom is: fiona.Geometry(coordinates=[[(-75.054818, 40.065839), ...]], type='Polygon')
# The neighborhod is: 033702
# geom is: fiona.Geometry(coordinates=[[(-75.069811, 40.070862), ...]], type='Polygon')
# The neighborhod is: 020102
# geom is: fiona.Geometry(coordinates=[[(-75.157945, 40.008486), ...]], type='Polygon')
# The neighborhod is: 031101
# geom is: fiona.Geometry(coordinates=[[(-75.082448, 40.042646), ...]], type='Polygon')
# The neighborhod is: 031102
# geom is: fiona.Geometry(coordinates=[[(-75.087852, 40.036111), ...]], type='Polygon')
# The neighborhod is: 019502
# geom is: fiona.Geometry(coordinates=[[(-75.137669, 40.003645), ...]], type='Polygon')
# The neighborhod is: 019501
# geom is: fiona.Geometry(coordinates=[[(-75.138249, 40.000993), ...]], type='Polygon')
# The neighborhod is: 028902
# geom is: fiona.Geometry(coordinates=[[(-75.120059, 40.023049), ...]], type='Polygon')
# The neighborhod is: 033101
# geom is: fiona.Geometry(coordinates=[[(-75.045919, 40.039643), ...]], type='Polygon')
# The neighborhod is: 033102
# geom is: fiona.Geometry(coordinates=[[(-75.033824, 40.04466), ...]], type='Polygon')
# The neighborhod is: 031501
# geom is: fiona.Geometry(coordinates=[[(-75.053645, 40.033896), ...]], type='Polygon')
# The neighborhod is: 001102
# geom is: fiona.Geometry(coordinates=[[(-75.160117, 39.943400000000004), ...]], type='Polygon')
# The neighborhod is: 000803
# geom is: fiona.Geometry(coordinates=[[(-75.17775499999999, 39.948974), ...]], type='Polygon')
# The neighborhod is: 980900
# geom is: fiona.Geometry(coordinates=[[(-75.261078, 39.876604), ...]], type='Polygon')
# The neighborhod is: 017201
# geom is: fiona.Geometry(coordinates=[[(-75.172257, 39.99671), ...]], type='Polygon')
# The neighborhod is: 980800
# geom is: fiona.Geometry(coordinates=[[(-75.280266, 39.974964), ...]], type='Polygon')
# The neighborhod is: 008601
# geom is: fiona.Geometry(coordinates=[[(-75.222191, 39.953413), ...]], type='Polygon')
# The neighborhod is: 037700
# geom is: fiona.Geometry(coordinates=[[(-75.15725499999999, 39.981693), ...]], type='Polygon')
# The neighborhod is: 980000
# geom is: fiona.Geometry(coordinates=[[(-75.227023, 39.983261999999996), ...]], type='Polygon')
# The neighborhod is: 010700
# geom is: fiona.Geometry(coordinates=[[(-75.212148, 39.973012), ...]], type='Polygon')
# The neighborhod is: 010800
# geom is: fiona.Geometry(coordinates=[[(-75.203722, 39.970929), ...]], type='Polygon')
# The neighborhod is: 010600
# geom is: fiona.Geometry(coordinates=[[(-75.211334, 39.968726), ...]], type='Polygon')
# The neighborhod is: 005400
# geom is: fiona.Geometry(coordinates=[[(-75.265147, 39.887316999999996), ...]], type='Polygon')
# The neighborhod is: 005500
# geom is: fiona.Geometry(coordinates=[[(-75.255597, 39.899595999999995), ...]], type='Polygon')
# The neighborhod is: 005600
# geom is: fiona.Geometry(coordinates=[[(-75.25232299999999, 39.897656), ...]], type='Polygon')
# The neighborhod is: 000500
# geom is: fiona.Geometry(coordinates=[[(-75.16529899999999, 39.952284), ...]], type='Polygon')
# The neighborhod is: 000700
# geom is: fiona.Geometry(coordinates=[[(-75.181663, 39.951509), ...]], type='Polygon')
# The neighborhod is: 034803
# geom is: fiona.Geometry(coordinates=[[(-75.00941399999999, 40.06208), ...]], type='Polygon')
# The neighborhod is: 006000
# geom is: fiona.Geometry(coordinates=[[(-75.24466799999999, 39.91558), ...]], type='Polygon')
# The neighborhod is: 006100
# geom is: fiona.Geometry(coordinates=[[(-75.234162, 39.915185), ...]], type='Polygon')
# The neighborhod is: 006300
# geom is: fiona.Geometry(coordinates=[[(-75.246898, 39.918574), ...]], type='Polygon')
# The neighborhod is: 006400
# geom is: fiona.Geometry(coordinates=[[(-75.247759, 39.921707999999995), ...]], type='Polygon')
# The neighborhod is: 026800
# geom is: fiona.Geometry(coordinates=[[(-75.14371799999999, 40.051300999999995), ...]], type='Polygon')
# The neighborhod is: 005000
# geom is: fiona.Geometry(coordinates=[[(-75.19623899999999, 39.893364999999996), ...]], type='Polygon')
# The neighborhod is: 014400
# geom is: fiona.Geometry(coordinates=[[(-75.14632, 39.971564), ...]], type='Polygon')
# The neighborhod is: 036600
# geom is: fiona.Geometry(coordinates=[[(-75.14636999999999, 39.930226), ...]], type='Polygon')
# The neighborhod is: 028100
# geom is: fiona.Geometry(coordinates=[[(-75.153241, 40.030105999999996), ...]], type='Polygon')
# The neighborhod is: 035302
# geom is: fiona.Geometry(coordinates=[[(-75.00483299999999, 40.070572999999996), ...]], type='Polygon')
# The neighborhod is: 002000
# geom is: fiona.Geometry(coordinates=[[(-75.188803, 39.937266), ...]], type='Polygon')
# The neighborhod is: 014300
# geom is: fiona.Geometry(coordinates=[[(-75.134428, 39.968790999999996), ...]], type='Polygon')
# The neighborhod is: 001101
# geom is: fiona.Geometry(coordinates=[[(-75.16557499999999, 39.943664), ...]], type='Polygon')
# The neighborhod is: 027402
# geom is: fiona.Geometry(coordinates=[[(-75.128311, 40.033015999999996), ...]], type='Polygon')
# The neighborhod is: 036502
# geom is: fiona.Geometry(coordinates=[[(-75.009147, 40.12202), ...]], type='Polygon')
# The neighborhod is: 000401
# geom is: fiona.Geometry(coordinates=[[(-75.180909, 39.952982), ...]], type='Polygon')
# The neighborhod is: 034501
# geom is: fiona.Geometry(coordinates=[[(-75.042872, 40.077400000000004), ...]], type='Polygon')
# The neighborhod is: 000901
# geom is: fiona.Geometry(coordinates=[[(-75.164845, 39.946999), ...]], type='Polygon')
# The neighborhod is: 017702
# geom is: fiona.Geometry(coordinates=[[(-75.126915, 39.991834), ...]], type='Polygon')
# The neighborhod is: 023800
# geom is: fiona.Geometry(coordinates=[[(-75.188797, 40.03948), ...]], type='Polygon')
# The neighborhod is: 010900
# geom is: fiona.Geometry(coordinates=[[(-75.19530999999999, 39.968045), ...]], type='Polygon')
# The neighborhod is: 024800
# geom is: fiona.Geometry(coordinates=[[(-75.17175499999999, 40.048359), ...]], type='Polygon')
# The neighborhod is: 018800
# geom is: fiona.Geometry(coordinates=[[(-75.11322899999999, 39.996579), ...]], type='Polygon')
# The neighborhod is: 033500
# geom is: fiona.Geometry(coordinates=[[(-75.071592, 40.057103999999995), ...]], type='Polygon')
# The neighborhod is: 007700
# geom is: fiona.Geometry(coordinates=[[(-75.21292, 39.949065), ...]], type='Polygon')
# The neighborhod is: 014000
# geom is: fiona.Geometry(coordinates=[[(-75.167638, 39.971526), ...]], type='Polygon')
# The neighborhod is: 003001
# geom is: fiona.Geometry(coordinates=[[(-75.175468, 39.928065), ...]], type='Polygon')
# The neighborhod is: 002802
# geom is: fiona.Geometry(coordinates=[[(-75.167074, 39.926798), ...]], type='Polygon')
# The neighborhod is: 980700
# geom is: fiona.Geometry(coordinates=[[(-75.17491799999999, 39.898603), ...]], type='Polygon')
# The neighborhod is: 002701
# geom is: fiona.Geometry(coordinates=[[(-75.155997, 39.925532), ...]], type='Polygon')
# The neighborhod is: 980600
# geom is: fiona.Geometry(coordinates=[[(-75.183142, 39.907748), ...]], type='Polygon')
# The neighborhod is: 034702
# geom is: fiona.Geometry(coordinates=[[(-75.036467, 40.053965), ...]], type='Polygon')
# The neighborhod is: 034801
# geom is: fiona.Geometry(coordinates=[[(-75.024818, 40.060286), ...]], type='Polygon')
# The neighborhod is: 034802
# geom is: fiona.Geometry(coordinates=[[(-75.021839, 40.063258999999995), ...]], type='Polygon')
# The neighborhod is: 034900
# geom is: fiona.Geometry(coordinates=[[(-75.021984, 40.037965), ...]], type='Polygon')
# The neighborhod is: 035100
# geom is: fiona.Geometry(coordinates=[[(-74.995496, 40.047664), ...]], type='Polygon')
# The neighborhod is: 004201
# geom is: fiona.Geometry(coordinates=[[(-75.1555, 39.920449999999995), ...]], type='Polygon')
# The neighborhod is: 028800
# geom is: fiona.Geometry(coordinates=[[(-75.128883, 40.018944999999995), ...]], type='Polygon')
# The neighborhod is: 011700
# geom is: fiona.Geometry(coordinates=[[(-75.247948, 39.991138), ...]], type='Polygon')
# The neighborhod is: 016902
# geom is: fiona.Geometry(coordinates=[[(-75.187608, 39.996575), ...]], type='Polygon')
# The neighborhod is: 001400
# geom is: fiona.Geometry(coordinates=[[(-75.177554, 39.942487), ...]], type='Polygon')
# The neighborhod is: 013200
# geom is: fiona.Geometry(coordinates=[[(-75.16111, 39.963788), ...]], type='Polygon')
# The neighborhod is: 027000
# geom is: fiona.Geometry(coordinates=[[(-75.138759, 40.048558), ...]], type='Polygon')
# The neighborhod is: 035602
# geom is: fiona.Geometry(coordinates=[[(-75.054321, 40.108692), ...]], type='Polygon')
# The neighborhod is: 015101
# geom is: fiona.Geometry(coordinates=[[(-75.18795, 39.98453), ...]], type='Polygon')
# The neighborhod is: 015102
# geom is: fiona.Geometry(coordinates=[[(-75.184709, 39.984111), ...]], type='Polygon')
# The neighborhod is: 031402
# geom is: fiona.Geometry(coordinates=[[(-75.065243, 40.040776), ...]], type='Polygon')
# The neighborhod is: 016701
# geom is: fiona.Geometry(coordinates=[[(-75.16409399999999, 39.995169), ...]], type='Polygon')
# The neighborhod is: 027901
# geom is: fiona.Geometry(coordinates=[[(-75.15828499999999, 40.043341), ...]], type='Polygon')
# The neighborhod is: 027902
# geom is: fiona.Geometry(coordinates=[[(-75.159151, 40.035575), ...]], type='Polygon')
# The neighborhod is: 008702
# geom is: fiona.Geometry(coordinates=[[(-75.20932599999999, 39.951436), ...]], type='Polygon')
# The neighborhod is: 008101
# geom is: fiona.Geometry(coordinates=[[(-75.239958, 39.94641), ...]], type='Polygon')
# The neighborhod is: 007102
# geom is: fiona.Geometry(coordinates=[[(-75.233632, 39.940292), ...]], type='Polygon')
# The neighborhod is: 008701
# geom is: fiona.Geometry(coordinates=[[(-75.212947, 39.949129), ...]], type='Polygon')
# The neighborhod is: 008102
# geom is: fiona.Geometry(coordinates=[[(-75.239009, 39.950948), ...]], type='Polygon')
# The neighborhod is: 001002
# geom is: fiona.Geometry(coordinates=[[(-75.150651, 39.94234), ...]], type='Polygon')
# The neighborhod is: 030502
# geom is: fiona.Geometry(coordinates=[[(-75.111153, 40.042187), ...]], type='Polygon')
# The neighborhod is: 031502
# geom is: fiona.Geometry(coordinates=[[(-75.061043, 40.037980999999995), ...]], type='Polygon')

# %% [markdown]
# Here you may find we are using dictionary to manage the metadata and the geometry of each feature in the shapefile

# %%
feat
# Out:
# fiona.Feature(geometry=fiona.Geometry(coordinates=[[(-75.061043, 40.037980999999995), ...]], type='Polygon'), id='383', properties=fiona.Properties(STATEFP='42', COUNTYFP='101', TRACTCE='031502', GEOID='42101031502', NAME_x='315.02', NAMELSAD='Census Tract 315.02', MTFCC='G5020', FUNCSTAT='S', ALAND=578102, AWATER=0, INTPTLAT='+40.0392658', INTPTLON='-075.0548693', NAME_y='Census Tract 315.02, Philadelphia County, Pennsylvania', GEO_ID='1400000US42101031502', white_popu='2441', non-hispan='2258', black_popu='843', asian_popu='676', hispanic_p='510', total_popu='4461', median_hou='43190', per_capita='18873', built_age='1627', less_highs='600', bachelor='348', totaleduca='3120', male_und18='530', female_und='535', male65_66='19', male67_69='101', male70_74='40', male75_79='11', male80_84='15', male85_='40', fema_65_66='74', fema_67_69='21', fema70_74='51', fema75_79='48', fema80_84='31', fema85_='22', state='42', county='101', tract='031502'))

# %%
feat['properties'].items()
# Out:
# ItemsView(fiona.Properties(STATEFP='42', COUNTYFP='101', TRACTCE='031502', GEOID='42101031502', NAME_x='315.02', NAMELSAD='Census Tract 315.02', MTFCC='G5020', FUNCSTAT='S', ALAND=578102, AWATER=0, INTPTLAT='+40.0392658', INTPTLON='-075.0548693', NAME_y='Census Tract 315.02, Philadelphia County, Pennsylvania', GEO_ID='1400000US42101031502', white_popu='2441', non-hispan='2258', black_popu='843', asian_popu='676', hispanic_p='510', total_popu='4461', median_hou='43190', per_capita='18873', built_age='1627', less_highs='600', bachelor='348', totaleduca='3120', male_und18='530', female_und='535', male65_66='19', male67_69='101', male70_74='40', male75_79='11', male80_84='15', male85_='40', fema_65_66='74', fema_67_69='21', fema70_74='51', fema75_79='48', fema80_84='31', fema85_='22', state='42', county='101', tract='031502'))

# %% [markdown]
# List all the items

# %%
dict(feat['properties'].items())
# Out:
# {'STATEFP': '42',
#  'COUNTYFP': '101',
#  'TRACTCE': '031502',
#  'GEOID': '42101031502',
#  'NAME_x': '315.02',
#  'NAMELSAD': 'Census Tract 315.02',
#  'MTFCC': 'G5020',
#  'FUNCSTAT': 'S',
#  'ALAND': 578102,
#  'AWATER': 0,
#  'INTPTLAT': '+40.0392658',
#  'INTPTLON': '-075.0548693',
#  'NAME_y': 'Census Tract 315.02, Philadelphia County, Pennsylvania',
#  'GEO_ID': '1400000US42101031502',
#  'white_popu': '2441',
#  'non-hispan': '2258',
#  'black_popu': '843',
#  'asian_popu': '676',
#  'hispanic_p': '510',
#  'total_popu': '4461',
#  'median_hou': '43190',
#  'per_capita': '18873',
#  'built_age': '1627',
#  'less_highs': '600',
#  'bachelor': '348',
#  'totaleduca': '3120',
#  'male_und18': '530',
#  'female_und': '535',
#  'male65_66': '19',
#  'male67_69': '101',
#  'male70_74': '40',
#  'male75_79': '11',
#  'male80_84': '15',
#  'male85_': '40',
#  'fema_65_66': '74',
#  'fema_67_69': '21',
#  'fema70_74': '51',
#  'fema75_79': '48',
#  'fema80_84': '31',
#  'fema85_': '22',
#  'state': '42',
#  'county': '101',
#  'tract': '031502'}

# %% [markdown]
# For the geometry, we can do the same

# %%
geom = feat['geometry']
dict(geom)['coordinates']
# Out:
# [[(-75.061043, 40.037980999999995),
#   (-75.060386, 40.0386),
#   (-75.059801, 40.039152),
#   (-75.05910999999999, 40.039803),
#   (-75.05879399999999, 40.0401),
#   (-75.058555, 40.040310999999996),
#   (-75.058504, 40.040358999999995),
#   (-75.057182, 40.04161),
#   (-75.056709, 40.042058999999995),
#   (-75.05654899999999, 40.042218999999996),
#   (-75.056122, 40.042645),
#   (-75.05594599999999, 40.042831),
#   (-75.05561, 40.043186999999996),
#   (-75.05492699999999, 40.043853999999996),
#   (-75.054287, 40.044447999999996),
#   (-75.054262, 40.044435),
#   (-75.05406099999999, 40.044325),
#   (-75.053114, 40.043763999999996),
#   (-75.052228, 40.043271),
#   (-75.05215299999999, 40.043209999999995),
#   (-75.051425, 40.042788),
#   (-75.050643, 40.042333),
#   (-75.049027, 40.041412),
#   (-75.04911, 40.041337),
#   (-75.049596, 40.040805999999996),
#   (-75.050091, 40.040285),
#   (-75.050617, 40.039736),
#   (-75.05122, 40.039091),
#   (-75.05151599999999, 40.038778),
#   (-75.0518, 40.038475999999996),
#   (-75.05239399999999, 40.037849),
#   (-75.053022, 40.037183),
#   (-75.053319, 40.036857999999995),
#   (-75.053584, 40.036574),
#   (-75.05197299999999, 40.035672),
#   (-75.052525, 40.035087),
#   (-75.053072, 40.034501999999996),
#   (-75.053122, 40.034458),
#   (-75.053393, 40.034165),
#   (-75.053645, 40.033896),
#   (-75.05370099999999, 40.033843999999995),
#   (-75.055334, 40.034738999999995),
#   (-75.05695, 40.035651),
#   (-75.058568, 40.036547999999996),
#   (-75.059867, 40.037267),
#   (-75.06017899999999, 40.037456999999996),
#   (-75.060542, 40.037653999999996),
#   (-75.06092699999999, 40.037873999999995),
#   (-75.061043, 40.037980999999995)]]

# %% [markdown]
# we can also visualize the shape using the submodule `shape` in the module of `shapely`

# %%
shape(geom)
# Out:
# <POLYGON ((-75.061 40.038, -75.06 40.039, -75.06 40.039, -75.059 40.04, -75....>

# %% [markdown]
# Buffer analysis

# %%
shape(geom).buffer(10)
# Out:
# <POLYGON ((-81.992 47.24, -81.995 47.244, -81.989 47.249, -81.923 47.311, -8...>

# %% [markdown]
# What? Why has it become a round circle? This is because the unit is the degree, 10-degree is a pretty large distance. We need to reproject the geometry into the local projection with the unit of `m` or `ft`

# %% [markdown]
# Reproject feature using `pyproj`

# %%
from pyproj import Transformer
from shapely.ops import transform

# Define a transformer to convert from EPSG:4326 to EPSG:3857
transformer = Transformer.from_crs("EPSG:4269", "EPSG:2272", always_xy=True)

# Reproject the geometry
reprojected_geom = transform(transformer.transform, shape(geom))

# %%
reprojected_geom
# Out:
# <POLYGON ((2721301.327 268155.088, 2721478.338 268386.076, 2721635.938 26859...>

# %%
reprojected_geom.buffer(100)
# Out:
# <POLYGON ((2721226.488 268088.762, 2721220.328 268096.443, 2721214.954 26810...>

# %% [markdown]
# Write a shapefile using `fiona`, let save the buffered shapefile

# %%
from shapely.geometry import Point, mapping
import pandas

# prepare the schema and crs of the output shapefile
schema = {
    'geometry': 'Point',
    'properties': {
        'id': 'str: 20',
        'name': 'str: 20',
        'address': 'str: 20',
        'city': 'str: 20',
        'state':'str: 20',
        'zip': 'str: 7'
    }
}

crs = {'init': u'epsg:4326'}

# read the CSV file using pandas
coffee_shop_sheet = pandas.read_csv('data/cambridge_coffee_shops.csv')


# The output shapefile
coffee_shop_shp = 'data/cambridge_coffee_shops2.shp' 

with fiona.open(coffee_shop_shp, 'w', driver = "ESRI Shapefile", crs = crs, schema=schema) as output:
    for row in coffee_shop_sheet.iterrows():
        lon = row[1][7]
        lat = row[1][6]
        
        id_ = row[1][0]
        name = row[1][1]
        address = row[1][2]
        city = row[1][3]
        state = row[1][4]
        zipcode = row[1][5]
        
        point = Point(float(lon), float(lat))
        output.write({'properties':{'id': id_,
                                    'name': name,
                                    'address': address,
                                    'city': city,
                                    'state': state,
                                    'zip': zipcode
                                    },
                      'geometry': mapping(point)
                     })
        
print ('You have export the shapefile successfully')
# Out:
# You have export the shapefile successfully
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lon = row[1][7]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lat = row[1][6]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   id_ = row[1][0]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   name = row[1][1]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   address = row[1][2]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city = row[1][3]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   state = row[1][4]
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\946403483.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   zipcode = row[1][5]

# %%
coffee_shop_shp
# Out:
# 'data/cambridge_coffee_shops2.shp'

# %%
# # Update the feature geometry with the reprojected geometry
feat["geometry"] = mapping(reprojected_geom)

# # Write the feature to the output shapefile
dst.write(feat)
# Out:
# C:\Users\Tess\AppData\Local\Temp\ipykernel_15660\4047081397.py:2: FionaDeprecationWarning: instances of this class -- CRS, geometry, and feature objects -- will become immutable in fiona version 2.0
#   feat["geometry"] = mapping(reprojected_geom)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       2 feat["geometry"] = mapping(reprojected_geom)
#       4 # # Write the feature to the output shapefile
# ----> 5 dst.write(feat)
#
# NameError: name 'dst' is not defined
